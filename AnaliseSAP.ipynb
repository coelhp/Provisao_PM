# %%
import pandas as pd

# Load IW29.xlsx
df_iw29 = pd.read_excel('IW29.xlsx')
print('Data types for IW29.xlsx:')
df_iw29.info()
# Out:
# Data types for IW29.xlsx:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64192 entries, 0 to 64191
# Data columns (total 42 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Dt.referência    64192 non-null  datetime64[ns]
#  1   Data da nota     64192 non-null  datetime64[ns]
#  2   Dt.criação       64192 non-null  datetime64[ns]
#  3   Loc.instalação   64192 non-null  object
#  4   Denominação      64192 non-null  object
#  5   Equipamento      17290 non-null  object
#  6   Denominação.1    17290 non-null  object
#  7   Código ABC       48202 non-null  object
#  8   Localização      64171 non-null  float64
#  9   Área operacion.  57191 non-null  float64
#  10  Descrição        64028 non-null  object
#  11  Nota             64192 non-null  int64
#  12  Ordem            62533 non-null  float64
#  13  Tipo de nota     64192 non-null  object
#  14  Início desejado  63347 non-null  datetime64[ns]
# ...

# %%
# Imprimindo a lista de colunas
print(df_iw29.columns)
# Out:
# Index(['Dt.referência', 'Data da nota', 'Dt.criação', 'Loc.instalação',
#        'Denominação', 'Equipamento', 'Denominação.1', 'Código ABC',
#        'Localização', 'Área operacion.', 'Descrição', 'Nota', 'Ordem',
#        'Tipo de nota', 'Início desejado', 'Concl.desejada', 'Data encermto.',
#        'CenTrab respon.', 'Prioridade', 'Notificador', 'Status sistema',
#        'Modificado por', 'Cen.p/cen.trab.', 'Tipo prioridade', 'Empresa',
#        'Criado por', 'Local/ClasContb', 'Txt.descritivo', 'Grp.plnj.PM',
#        'Centro planej.', 'Área Cont.Csts.', 'Centro custo', 'Status usuário',
#        'Cen.manutenção', 'Centro p/CenTrb', 'Plano manut.', 'Parada',
#        'InícioAvar', 'HoraInícioAvar.', 'Fim avaria', 'Hora fim avaria',
#        'Duraç.parada'],
#       dtype='object')

# %%
# Load IW37N.xlsx
df_iw37n = pd.read_excel('IW37N.xlsx')
print('\nData types for IW37N.xlsx:')
df_iw37n.info()
# Out:
# Data types for IW37N.xlsx:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171385 entries, 0 to 171384
# Data columns (total 28 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Cen.manutenção   171385 non-null  int64
#  1   Nota             171289 non-null  float64
#  2   Ordem            171385 non-null  int64
#  3   Texto breve      171314 non-null  object
#  4   Operação         171385 non-null  int64
#  5   TxtDesc.Oper.    169458 non-null  object
#  6   CenTrabOperação  171385 non-null  object
#  7   CenTrab respon.  171385 non-null  object
#  8   Loc.instalação   171385 non-null  object
#  9   Denominação      171385 non-null  object
#  10  Tp.atvd.manut.   170590 non-null  float64
#  11  Tipo de ordem    171385 non-null  object
#  12  Prioridade       168662 non-null  float64
#  13  Centro custo     171385 non-null  int64
#  14  Data de entrada  171385 non-null  datetime64[ns]
# ...

# %%
# Imprimindo a lista de colunas
print(df_iw37n.columns)
# Out:
# Index(['Cen.manutenção', 'Nota', 'Ordem', 'Texto breve', 'Operação',
#        'TxtDesc.Oper.', 'CenTrabOperação', 'CenTrab respon.', 'Loc.instalação',
#        'Denominação', 'Tp.atvd.manut.', 'Tipo de ordem', 'Prioridade',
#        'Centro custo', 'Data de entrada', 'Data-base iníc.', 'Data-base fim',
#        'Status sistema', 'Duração normal', 'Trabalho', 'Trabalho real',
#        'Unidade trab.', 'ReqC', 'Reserva/ReqComp', 'Item RC', 'Código ABC',
#        'Plano manut.', 'Revisão'],
#       dtype='object')

# %%
# Load IW39.xlsx
df_iw39 = pd.read_excel('IW39.xlsx')
print('\nData types for IW39.xlsx:')
df_iw39.info()
# Out:
# Data types for IW39.xlsx:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84231 entries, 0 to 84230
# Data columns (total 57 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Ordem            84231 non-null  int64
#  1   Data de entrada  84231 non-null  datetime64[ns]
#  2   Loc.instalação   84230 non-null  object
#  3   Denominação      84230 non-null  object
#  4   Equipamento      23346 non-null  object
#  5   Denominação.1    23346 non-null  object
#  6   Tipo de ordem    84231 non-null  object
#  7   Texto breve      84133 non-null  object
#  8   Status sistema   84231 non-null  object
#  9   Centro custo     84231 non-null  int64
#  10  Código ABC       64983 non-null  object
#  11  Localização      84204 non-null  float64
#  12  Área operacion.  75923 non-null  float64
#  13  Nota             84011 non-null  float64
#  14  CenTrab respon.  84231 non-null  object
#  15  Cust.tot.reais   84231 non-null  float64
# ...

# %%
# Imprimindo a lista de colunas
print(df_iw39.columns)
# Out:
# Index(['Ordem', 'Data de entrada', 'Loc.instalação', 'Denominação',
#        'Equipamento', 'Denominação.1', 'Tipo de ordem', 'Texto breve',
#        'Status sistema', 'Centro custo', 'Código ABC', 'Localização',
#        'Área operacion.', 'Nota', 'CenTrab respon.', 'Cust.tot.reais',
#        'Custos tot.plan', 'Dt.referência', 'Modificado por', 'Centro trabalho',
#        'Tipo prioridade', 'Categoria ordem', 'Cntr.cntr.trab.', 'Conjunto',
#        'Denom.conjunto', 'Empresa', 'Criado por', 'Liberação real',
#        'Rec.tot.reais', 'Rec.totais plan', 'Total real', 'Total planejado',
#        'Dt.real fim', 'Data-base fim', 'Fim programado', 'Dta.início real',
#        'Data-base iníc.', 'Início prog.', 'Tp.atvd.manut.', 'Grp.plnj.PM',
#        'Centro planej.', 'Esq.cálc.custos', 'Item', 'Área Cont.Csts.',
#        'Cen.cst.respons', 'Nº objeto', 'Status paging', 'Cód.plan.ordem',
#        'Centro de lucro', 'Prioridade', 'Cen.manutenção', 'Status usuário',
# ...
